# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import pickle

# %%
data=pd.read_csv('/content/DS_Internship_Learnsmasher/Student_Marks.csv') # importing the data set

# %%
data
# Out:
#     number_courses  time_study   Marks
# 0                3       4.508  19.202
# 1                4       0.096   7.734
# 2                4       3.133  13.811
# 3                6       7.909  53.018
# 4                8       7.811  55.299
# ..             ...         ...     ...
# 95               6       3.561  19.128
# 96               3       0.301   5.609
# 97               4       7.163  41.444
# 98               7       0.309  12.027
# 99               3       6.335  32.357
#
# [100 rows x 3 columns]

# %%
sns.heatmap(data)
# Out:
# <Axes: >

# %%
data.head(10)
# Out:
#    number_courses  time_study   Marks
# 0               3       4.508  19.202
# 1               4       0.096   7.734
# 2               4       3.133  13.811
# 3               6       7.909  53.018
# 4               8       7.811  55.299
# 5               6       3.211  17.822
# 6               3       6.063  29.889
# 7               5       3.413  17.264
# 8               4       4.410  20.348
# 9               3       6.173  30.862

# %%
data.tail(10)
# Out:
#     number_courses  time_study   Marks
# 90               7       4.182  24.394
# 91               8       2.730  19.564
# 92               4       5.027  23.916
# 93               8       6.471  42.426
# 94               8       3.919  24.451
# 95               6       3.561  19.128
# 96               3       0.301   5.609
# 97               4       7.163  41.444
# 98               7       0.309  12.027
# 99               3       6.335  32.357

# %%
data.shape
# Out:
# (100, 3)

# %%
data.columns
# Out:
# Index(['number_courses', 'time_study', 'Marks'], dtype='object')

# %%
len(data.columns)
# Out:
# 3

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 3 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   number_courses  100 non-null    int64
#  1   time_study      100 non-null    float64
#  2   Marks           100 non-null    float64
# dtypes: float64(2), int64(1)
# memory usage: 2.5 KB

# %%
data.describe()
# Out:
#        number_courses  time_study       Marks
# count      100.000000  100.000000  100.000000
# mean         5.290000    4.077140   24.417690
# std          1.799523    2.372914   14.326199
# min          3.000000    0.096000    5.609000
# 25%          4.000000    2.058500   12.633000
# 50%          5.000000    4.022000   20.059500
# 75%          7.000000    6.179250   36.676250
# max          8.000000    7.957000   55.299000

# %%
data.isnull().count()
# Out:
# number_courses    100
# time_study        100
# Marks             100
# dtype: int64

# %%
data.isnull()
# Out:
#     number_courses  time_study  Marks
# 0            False       False  False
# 1            False       False  False
# 2            False       False  False
# 3            False       False  False
# 4            False       False  False
# ..             ...         ...    ...
# 95           False       False  False
# 96           False       False  False
# 97           False       False  False
# 98           False       False  False
# 99           False       False  False
#
# [100 rows x 3 columns]

# %%
data.isnull().sum(axis=0)
# Out:
# number_courses    0
# time_study        0
# Marks             0
# dtype: int64

# %%
data.isnull().sum(axis=1)
# Out:
# 0     0
# 1     0
# 2     0
# 3     0
# 4     0
#      ..
# 95    0
# 96    0
# 97    0
# 98    0
# 99    0
# Length: 100, dtype: int64

# %%
import matplotlib.pyplot as plt

x1 = data["number_courses"]
y1 = data["Marks"]

x2 = data["time_study"]
y2 = data["Marks"]

plt.figure(figsize=(15, 10))  # Adjust the figure size if needed

plt.subplot(1, 2, 1)
plt.plot(x1, y1, color='blue')  # Change the color to blue
plt.title("number_courses vs.Marks")
plt.xlabel("number_courses")
plt.ylabel("Marks")

plt.subplot(1, 2, 2)
plt.plot(x2, y2, color='green')  # Change the color to green
plt.title("time_study vs. Marks")
plt.xlabel("time_study")
plt.ylabel("Marks")

plt.tight_layout()  # Adjust subplot spacing for better visualization
plt.show()

# %%
data.sum()
# Out:
# number_courses     529.000
# time_study         407.714
# Marks             2441.769
# dtype: float64

# %%
data.max()
# Out:
# number_courses     8.000
# time_study         7.957
# Marks             55.299
# dtype: float64

# %%
data.min()
# Out:
# number_courses    3.000
# time_study        0.096
# Marks             5.609
# dtype: float64

# %%
data.mean()
# Out:
# number_courses     5.29000
# time_study         4.07714
# Marks             24.41769
# dtype: float64

# %%
# Visualizing the relationship between a "number_courses" feature and "Marks" response
plt.figure(figsize=(8, 6))

data.plot(kind='scatter', x='number_courses', y='Marks')
plt.xlabel('number_courses')
plt.ylabel('Marks')
plt.title('Scatter Plot: number_courses vs. Marks')

plt.show()

# %%
# Visualizing the relationship between a "time_study   " feature and "Marks" response
plt.figure(figsize=(8, 6))

data.plot(kind='scatter', x='time_study', y='Marks')
plt.xlabel('time_study ')
plt.ylabel('Marks')
plt.title('Scatter Plot: time_study  vs. Marks')

plt.show()

# %%
import plotly.express as px
import plotly.graph_objects as go
figure=px.scatter(data_frame=data,x='Marks',y="number_courses",size="number_courses",trendline="ols")
figure.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
features = data.iloc[:, :-1]
features
# Out:
#     number_courses  time_study
# 0                3       4.508
# 1                4       0.096
# 2                4       3.133
# 3                6       7.909
# 4                8       7.811
# ..             ...         ...
# 95               6       3.561
# 96               3       0.301
# 97               4       7.163
# 98               7       0.309
# 99               3       6.335
#
# [100 rows x 2 columns]

# %%
response=data.iloc[:,-1:]

response
# Out:
#      Marks
# 0   19.202
# 1    7.734
# 2   13.811
# 3   53.018
# 4   55.299
# ..     ...
# 95  19.128
# 96   5.609
# 97  41.444
# 98  12.027
# 99  32.357
#
# [100 rows x 1 columns]

# %%
import plotly.express as px
import plotly.graph_objects as go
figure=px.scatter(data_frame=data,x='Marks',y="time_study",size="time_study",trendline="ols")
figure.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
from sklearn.linear_model import LinearRegression

# %%
Model=LinearRegression()
Model.fit(features,response)
# Out:
# LinearRegression()

# %%
Intercept=float(Model.intercept_)
print("The intercept of the fitted model is:=", Intercept)
# Out:
# The intercept of the fitted model is:= -7.456346231178362

# %%
coeficient=Model.coef_
print("The Coefficient of the fitted model is:" , coeficient)
# Out:
# The Coefficient of the fitted model is: [[1.86405074 5.39917879]]
